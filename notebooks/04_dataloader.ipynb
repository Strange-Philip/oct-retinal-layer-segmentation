# %%
import os
import sys

PROJECT_ROOT = os.path.abspath("..")

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print(PROJECT_ROOT)
from pathlib import Path
from src.io import load_dataset
from src.training.split import split_subjects
from src.training.loaders import create_loaders

subjects = load_dataset("../datasets/duke/2015_BOE_Chiu")

print(len(subjects))
# Out:
# /Users/philipabakah/Desktop/projects/explore/oct-retinal-layer-segmentation
# 10

# %%
train_subjects, val_subjects = split_subjects(subjects)

print(len(train_subjects))
print(len(val_subjects))
# Out:
# 8
# 2

# %%
train_loader, val_loader = create_loaders(
    train_subjects,
    val_subjects,
    batch_size=4,
)

# %%
images, masks = next(iter(train_loader))

print(images.shape)
print(images.dtype)

print(masks.shape)
print(masks.dtype)
# Out:
# torch.Size([4, 1, 496, 768])
# torch.float32
# torch.Size([4, 496, 768])
# torch.int64
# /opt/homebrew/Caskroom/miniforge/base/envs/oct-research/lib/python3.11/site-packages/torch/utils/data/dataloader.py:759: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)

# %%
print(images.min(), images.max())
# Out:
# tensor(0.) tensor(1.)

# %%
import torch
print(torch.unique(masks))
# Out:
# tensor([0, 1, 2, 3, 4, 5, 6, 7])

# %%
import torch
import os
import sys

PROJECT_ROOT = os.path.abspath("..")

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print(PROJECT_ROOT)
from pathlib import Path
from src.models.unet import UNet
from src.training.losses import create_cross_entropy_loss

model = UNet(
    n_channels=1,
    n_classes=8,
)

criterion = create_cross_entropy_loss()

images = torch.randn(2,1,496,768)

targets = torch.randint(
    low=0,
    high=8,
    size=(2,496,768),
)

outputs = model(images)

print(outputs.shape)
print(targets.shape)
# Out:
# /Users/philipabakah/Desktop/projects/explore/oct-retinal-layer-segmentation
# torch.Size([2, 8, 496, 768])
# torch.Size([2, 496, 768])

# %%
loss = criterion(outputs, targets)

print(loss)
# Out:
# tensor(2.1343, grad_fn=<NllLoss2DBackward0>)
